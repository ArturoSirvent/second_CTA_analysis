# %% [markdown]
# Para cargar los datos en memria voy a usar funciones básicas.

# %%
import numpy as np
import matplotlib.pyplot as plt 
import pickle

#importamos librerias

import sys
sys.path.append('../src/CTA-data-analisis-library/')
import os 
import subprocess
from datetime import datetime
import numpy as np 
from glob import glob
import matplotlib.pyplot as plt
import tensorflow as tf 
import psutil
import re
import random
import shutil
import pickle
from numba import cuda
import gc

#propias
import unzipdata_and_first_treatments as manipulate
import loaddata4use
import model_creation_functions as models

# %%
aux1=[]
aux3=[]
for i in range(1,8):
    with open(f"../modelos/performances/003_history_modelo_filtro_0_en_boostrap_stage_{i}_energy.pickle","rb") as fil:
        hist=pickle.load(fil)
        aux1.append(hist.history["loss"])
        aux3.append(hist.history["val_loss"])
# Out:
# 2023-01-11 17:41:09.341154: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-11 17:41:09.342579: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_847789/3163913988.py in <module>
#       3 for i in range(1,8):
#       4     with open(f"../modelos/performances/002_history_modelo_filtro_0_en_boostrap_stage_{i}_energy.pickle","rb") as fil:
# ----> 5         hist=pickle.load(fil)
#       6         aux1.append(hist.history["loss"])
#       7         aux3.append(hist.history["val_loss"])
#
# ~/.conda/envs/tenflow/lib/python3.7/site-packages/keras/saving/pickle_utils.py in deserialize_model_from_bytecode(serialized_model)
#      46         with tf.io.gfile.GFile(dest_path, "wb") as f:
#      47           f.write(archive.extractfile(name).read())
# ---> 48   model = save_module.load_model(temp_dir)
#      49   tf.io.gfile.rmtree(temp_dir)
#      50   return model
#
# ~/.conda/envs/tenflow/lib/python3.7/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/.conda/envs/tenflow/lib/python3.7/site-packages/keras/saving/save.py in load_model(filepath, custom_objects, compile, options)
#     207
#     208           if tf.io.gfile.isdir(filepath_str):
# --> 209             return saved_model_load.load(filepath_str, compile, options)
#     210           else:
#     211             if h5py is None:
#
# ~/.conda/envs/tenflow/lib/python3.7/site-packages/keras/saving/saved_model/load.py in load(path, compile, options)
#     144   # Finalize the loaded layers and remove the extra tracked dependencies.
#     145   keras_loader.finalize_objects()
# --> 146   keras_loader.del_tracking()
#     147
#     148   model = loaded['root']
#
# ~/.conda/envs/tenflow/lib/python3.7/site-packages/keras/saving/saved_model/load.py in del_tracking(self)
#     300         continue
#     301       for name in PUBLIC_ATTRIBUTES:
# --> 302         node._delete_tracking(name)  # pylint: disable=protected-access
#     303
#     304       if isinstance(node, functional_lib.Functional):
#
# ~/.conda/envs/tenflow/lib/python3.7/site-packages/tensorflow/python/training/tracking/autotrackable.py in _delete_tracking(self, name)
#     140   def _delete_tracking(self, name):
#     141     """Removes the tracking of name."""
# --> 142     self._maybe_initialize_trackable()
#     143     if name in self._unconditional_dependency_names:
#     144       del self._unconditional_dependency_names[name]
#
# ~/.conda/envs/tenflow/lib/python3.7/site-packages/tensorflow/python/training/tracking/base.py in _method_wrapper(self, *args, **kwargs)
#     583   def _method_wrapper(self, *args, **kwargs):
#     584     previous_value = getattr(self, "_self_setattr_tracking", True)
# --> 585     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     586     try:
#     587       result = method(self, *args, **kwargs)
#
# ~/.conda/envs/tenflow/lib/python3.7/site-packages/keras/engine/training.py in __setattr__(self, name, value)
#     308     if all(
#     309         isinstance(v, (base_layer.Layer, tf.Variable)) or
# --> 310         base_layer_utils.has_weights(v) for v in tf.nest.flatten(value)):
#     311       try:
#     312         self._base_model_initialized
#
# ~/.conda/envs/tenflow/lib/python3.7/site-packages/keras/engine/training.py in <genexpr>(.0)
#     308     if all(
#     309         isinstance(v, (base_layer.Layer, tf.Variable)) or
# --> 310         base_layer_utils.has_weights(v) for v in tf.nest.flatten(value)):
#     311       try:
#     312         self._base_model_initialized
#
# KeyboardInterrupt:

# %%
aux2=[j for i in aux1 for j in i]
aux4=[j for i in aux3 for j in i]

# %%
plt.plot(aux2)
plt.plot(aux4)

# %% [markdown]
# ## Carga de datos de test

# %%
def runs_disponibles(npy_dir,elements):
    lista=[]
    for i in elements:
        npy_element_dir=os.path.join(npy_dir,"npy_"+i)
        runs=[int(re.search("run_([0-9]{3})_0\.npy",i).group(1)) for i in os.listdir(npy_element_dir) if re.search("run_([0-9]{3})_0\.npy",i)]
        lista.append(runs)
    return lista


def new_create_main_list_runs(number_runs_per_element,posibles_runs):
    #esto es aleatorio por defecto, porque es lo unico que necesito por ahora    
    final=[]
    for ind,lista_runs_element in enumerate(posibles_runs):
        final.append(random.sample(lista_runs_element,number_runs_per_element[ind]))
    return final

#tenemos que hacer un ligero cambio porque se estan cargando con los ejes cambiados
def cambiar_ejes_lista(lista):
    for i,j in enumerate(lista):
        lista[i]=np.swapaxes(j,1,2)
    return lista

# %%
#enviroment variables
npy_final_dir="../datos/elementos_npy_test"
base_dir_elementos="../datos/elementos"
elements=['gamma', 'electron']

# %%
chose_runs=runs_disponibles(npy_final_dir,elements)
list_runs=new_create_main_list_runs([2,11],chose_runs)#new_create_main_list_runs([2,6,6,6,6,6,6],chose_runs)

x_train_list,x_test_list,y_train_list,y_test_list=loaddata4use.load_dataset_energy(npy_final_dir,base_dir_elementos,elementos=['gamma', 'electron'],main_list_runs=list_runs,telescopios=[1,2,3,4],test_size=0.05,same_quant="all",verbose=True,fill=True)

x_train_list=cambiar_ejes_lista(x_train_list)
x_test_list=cambiar_ejes_lista(x_test_list)
# Out:
# Load of names and common events
# _______________
# Element:  gamma  , Runs:  [30, 8]  Shape of common events (common events, energies):  (4, 1111) (4, 1111)
# Element:  gamma  , Runs:  [30, 8]  Shape of common events (common events, energies):  (4, 1066) (4, 1066)
# Element:  electron  , Runs:  [57, 48, 71, 102, 78, 48, 6, 54, 78, 32, 6]  Shape of common events (common events, energies):  (4, 257) (4, 257)
# Element:  electron  , Runs:  [57, 48, 71, 102, 78, 48, 6, 54, 78, 32, 6]  Shape of common events (common events, energies):  (4, 253) (4, 253)
# Element:  electron  , Runs:  [57, 48, 71, 102, 78, 48, 6, 54, 78, 32, 6]  Shape of common events (common events, energies):  (4, 250) (4, 250)
# Element:  electron  , Runs:  [57, 48, 71, 102, 78, 48, 6, 54, 78, 32, 6]  Shape of common events (common events, energies):  (4, 253) (4, 253)
# Element:  electron  , Runs:  [57, 48, 71, 102, 78, 48, 6, 54, 78, 32, 6]  Shape of common events (common events, energies):  (4, 247) (4, 247)
# Element:  electron  , Runs:  [57, 48, 71, 102, 78, 48, 6, 54, 78, 32, 6]  Shape of common events (common events, energies):  (4, 253) (4, 253)
# Element:  electron  , Runs:  [57, 48, 71, 102, 78, 48, 6, 54, 78, 32, 6]  Shape of common events (common events, energies):  (4, 223) (4, 223)
# Element:  electron  , Runs:  [57, 48, 71, 102, 78, 48, 6, 54, 78, 32, 6]  Shape of common events (common events, energies):  (4, 241) (4, 241)
# Element:  electron  , Runs:  [57, 48, 71, 102, 78, 48, 6, 54, 78, 32, 6]  Shape of common events (common events, energies):  (4, 247) (4, 247)
# Element:  electron  , Runs:  [57, 48, 71, 102, 78, 48, 6, 54, 78, 32, 6]  Shape of common events (common events, energies):  (4, 264) (4, 264)
# Element:  electron  , Runs:  [57, 48, 71, 102, 78, 48, 6, 54, 78, 32, 6]  Shape of common events (common events, energies):  (4, 223) (4, 223)
# _______________
# Load of actual npy data:
# _______________
# Element:  gamma , Telescope:  1  Shape of loaded array (amount of images, size of images):  (2177, 93, 55)
# Energies vector shape: (2177,)
# Element:  electron , Telescope:  1  Shape of loaded array (amount of images, size of images):  (2711, 93, 55)
# Energies vector shape: (2711,)
# Final data shape (4888, 93, 55, 1) Final energies shape:  (4888,)
# _____________________
#
# Element:  gamma , Telescope:  2  Shape of loaded array (amount of images, size of images):  (2177, 93, 55)
# Element:  electron , Telescope:  2  Shape of loaded array (amount of images, size of images):  (2711, 93, 55)
# Element:  gamma , Telescope:  3  Shape of loaded array (amount of images, size of images):  (2177, 93, 55)
# Element:  electron , Telescope:  3  Shape of loaded array (amount of images, size of images):  (2711, 93, 55)
# Element:  gamma , Telescope:  4  Shape of loaded array (amount of images, size of images):  (2177, 93, 55)
# Element:  electron , Telescope:  4  Shape of loaded array (amount of images, size of images):  (2711, 93, 55)
# SUCCESS

# %%
#cargamos el ultimo modelo de los dos filtros:
modelos=[tf.keras.models.load_model(name) for name in glob("../modelos/003_modelo_filtro_*_en_boostrap_stage_18_energy.h5")]
"""
model_018=tf.keras.models.load_model("../modelos/003_modelo_filtro_0_en_boostrap_stage_18_energy.h5")
model_118=tf.keras.models.load_model("../modelos/003_modelo_filtro_1_en_boostrap_stage_18_energy.h5")
model_218=tf.keras.models.load_model("../modelos/003_modelo_filtro_2_en_boostrap_stage_18_energy.h5")
"""
# Out:
# 2023-01-20 13:56:18.884636: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-20 13:56:19.257572: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# '\nmodel_018=tf.keras.models.load_model("../modelos/003_modelo_filtro_0_en_boostrap_stage_18_energy.h5")\nmodel_118=tf.keras.models.load_model("../modelos/003_modelo_filtro_1_en_boostrap_stage_18_energy.h5")\nmodel_218=tf.keras.models.load_model("../modelos/003_modelo_filtro_2_en_boostrap_stage_18_energy.h5")\n'

# %%
y_preds=[model.predict(x_train_list).squeeze() for model in modelos]
# Out:
# 146/146 [==============================] - 297s 2s/step
# 146/146 [==============================] - 427s 3s/step
# 146/146 [==============================] - 110s 753ms/step

# %%
for i,y in enumerate(y_preds):
    plt.figure()
    plt.plot(y,y_train_list,".")
    plt.plot(np.arange(6),"--r")
    plt.xlim(0,4)
    plt.ylim(0,4)
    plt.savefig(f"../results/003_correlation_energy_filter_{i}.png")
