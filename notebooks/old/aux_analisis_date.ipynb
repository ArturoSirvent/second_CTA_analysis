# %%
import os 
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

# %%
with open("nohup_longExec.out","r") as fil:
    datos1=fil.read()

# %%
fechas=[datetime.strptime(i[-19:],"%d/%m/%Y %H:%M:%S") for i in datos1.split("\n")]
fechas_timestamp=[ i.timestamp() for i in fechas]

# %%
plt.plot(fechas_timestamp)

# %%
plt.hist(np.diff(fechas_timestamp));

# %%
print(len(fechas))
# Out:
# 36024

# %% [markdown]
# 35796

# %%
35796*30/60/60/24
# Out:
# 12.429166666666667

# %%
datetime.now()-fechas[0]
# Out:
# datetime.timedelta(days=12, seconds=44014, microseconds=786966)
